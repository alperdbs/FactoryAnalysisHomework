# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("MainFactories.csv")
data2 = pd.read_csv("AllFactories.csv")

# %%
data1
# Out:
#      Unnamed: 0   Factory     Ulke     SehIr       Tarih Kurulus_tarihi  \
# 0           0.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 1           1.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 2           2.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 3           3.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 4           4.0  FABRIKA2  TurkIye     Adana  12.05.2020      1.01.2012
# ..          ...       ...      ...       ...         ...            ...
# 96          NaN       NaN      NaN       NaN         NaN            NaN
# 97          NaN       NaN      NaN       NaN         NaN            NaN
# 98          NaN       NaN      NaN       NaN         NaN            NaN
# 99          NaN       NaN      NaN       NaN         NaN            NaN
# 100         NaN       NaN      NaN       NaN         NaN            NaN
#
#      Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# ...

# %%
data2
# Out:
#       Unnamed: 0      Factory     Ulke      Sehir       Tarih  Kurulus_tarihi  \
# 0              0     Factory1  Turkiye      Adana  12.05.2020            1980
# 1              1     Factory2  Turkiye   Istanbul  12.05.2020            1978
# 2              2     Factory3  Turkiye    Giresun  12.05.2020            1989
# 3              3     Factory4  Turkiye    Sakarya  12.05.2020            1969
# 4              4     Factory5  Turkiye     Ankara  12.05.2020            2000
# ...          ...          ...      ...        ...         ...             ...
# 996          996   Factory997  Turkiye       Rize  12.05.2020            1956
# 997          997   Factory998  Turkiye  Gumushane  12.05.2020            1976
# 998          998   Factory999  Turkiye    Malatya  12.05.2020            2019
# 999          999  Factory1000  Turkiye      Hatay  12.05.2020            2012
# 1000        1000  Factory1001  Turkiye    Kocaeli  12.05.2020            2009
#
# ...

# %%
data1_new=data1.dropna()

# %%
Isci = data1_new[["isci_sayisi","isci__memnuniyeti","Gunluk_calisma_suresi","Calisanlara_mesai","Mola_suresi","Calisan_tecrubesi","Vardiya","Ustabasilarinin_ise_onemvermesi"]]

# %%
Uretim = data1_new[["Aylik_uretim_miktari","Uretim_hizi","Gunluk_uretilen_miktar","Max_uretilen_urun","Fabrika_sayisi","Kapasite_durumu","Toplam_uretilmis_urun","Malzeme_kalitesi"]]

# %%
Mali= data1_new[["Urunbasi_ortalama_maliyet","Urunbasi_ortalama_kar","Max_fiyat","Min_fiyat","Max_kar","Max_zarar"]]

# %%
Musteri = data1_new[["Musteriye_hitap","Sosyal_medyayi_kullanma","Musteri_hizmetlerinin_ilgisi","Vergi_usulsuzlugu"]]

# %%
Muhasebe = data1_new[["Muhasebeci_tecrubesi","Kasada_acik_cikmasi","Malzeme_kaybi"]]

# %%
Yonetim= data1_new[["Patronlarin_donanimi","Globallesme_orani","Yanlis_marka_ismi","Pazar_payi","Yanlis_strateji","Sermayenin_tukenmesi","Is_yerindetorpil","Ortaklik_sorunlari"]]

# %%
sns.displot(Isci)

# %%
sns.displot(Uretim)

# %%
sns.displot(Mali)

# %%
sns.displot(Yonetim)

# %%
sns.displot(Muhasebe)
