# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("Bizimki.csv")
data2 = pd.read_csv("yaptık.csv")

# %%
data1
#Bize ait olan 10 fabrikanın verileri.
# Out:
#      Unnamed: 0   Factory     Ulke     SehIr       Tarih Kurulus_tarihi  \
# 0           0.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 1           1.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 2           2.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 3           3.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 4           4.0  FABRIKA2  TurkIye     Adana  12.05.2020      1.01.2012
# ..          ...       ...      ...       ...         ...            ...
# 96          NaN       NaN      NaN       NaN         NaN            NaN
# 97          NaN       NaN      NaN       NaN         NaN            NaN
# 98          NaN       NaN      NaN       NaN         NaN            NaN
# 99          NaN       NaN      NaN       NaN         NaN            NaN
# 100         NaN       NaN      NaN       NaN         NaN            NaN
#
#      Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# ...

# %%
data2
#anazlizi yapılacak fabrikalara ait olan 1000 fabrikanın verileri.
# Out:
#       Unnamed: 0      Factory     Ulke      Sehir       Tarih  Kurulus_tarihi  \
# 0              0     Factory1  Turkiye      Adana  12.05.2020            1980
# 1              1     Factory2  Turkiye   Istanbul  12.05.2020            1978
# 2              2     Factory3  Turkiye    Giresun  12.05.2020            1989
# 3              3     Factory4  Turkiye    Sakarya  12.05.2020            1969
# 4              4     Factory5  Turkiye     Ankara  12.05.2020            2000
# ...          ...          ...      ...        ...         ...             ...
# 996          996   Factory997  Turkiye       Rize  12.05.2020            1956
# 997          997   Factory998  Turkiye  Gumushane  12.05.2020            1976
# 998          998   Factory999  Turkiye    Malatya  12.05.2020            2019
# 999          999  Factory1000  Turkiye      Hatay  12.05.2020            2012
# 1000        1000  Factory1001  Turkiye    Kocaeli  12.05.2020            2009
#
# ...

# %%
data1.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0   Factory     Ulke     SehIr       Tarih Kurulus_tarihi  \
# 0           0.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 1           1.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 2           2.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 3           3.0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 4           4.0  FABRIKA2  TurkIye     Adana  12.05.2020      1.01.2012
# ..          ...       ...      ...       ...         ...            ...
# 96          NaN       NaN      NaN       NaN         NaN            NaN
# 97          NaN       NaN      NaN       NaN         NaN            NaN
# 98          NaN       NaN      NaN       NaN         NaN            NaN
# 99          NaN       NaN      NaN       NaN         NaN            NaN
# 100         NaN       NaN      NaN       NaN         NaN            NaN
#
#      Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# ...

# %%
data2.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0      Factory     Ulke      Sehir       Tarih  Kurulus_tarihi  \
# 0              0     Factory1  Turkiye      Adana  12.05.2020            1980
# 1              1     Factory2  Turkiye   Istanbul  12.05.2020            1978
# 2              2     Factory3  Turkiye    Giresun  12.05.2020            1989
# 3              3     Factory4  Turkiye    Sakarya  12.05.2020            1969
# 4              4     Factory5  Turkiye     Ankara  12.05.2020            2000
# ...          ...          ...      ...        ...         ...             ...
# 996          996   Factory997  Turkiye       Rize  12.05.2020            1956
# 997          997   Factory998  Turkiye  Gumushane  12.05.2020            1976
# 998          998   Factory999  Turkiye    Malatya  12.05.2020            2019
# 999          999  Factory1000  Turkiye      Hatay  12.05.2020            2012
# 1000        1000  Factory1001  Turkiye    Kocaeli  12.05.2020            2009
#
# ...

# %%
data1.describe()
# Out:
#        Unnamed: 0  Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# count   40.000000                 40.000000    40.000000          40.000000
# mean    19.500000                  3.600000  2869.000000           4.000000
# std     11.690452                  1.932184   718.391365           1.012739
# min      0.000000                  0.000000  1750.000000           2.000000
# 25%      9.750000                  3.000000  2250.000000           3.000000
# 50%     19.500000                  4.500000  2935.000000           4.000000
# 75%     29.250000                  5.000000  3530.000000           5.000000
# max     39.000000                  5.000000  3780.000000           5.000000
#
#        Aylik_uretim_miktari  Uretim_hizi  Gunluk_uretilen_miktar  \
# count             40.000000    40.000000                 40.0000
# mean          315500.000000     3.600000              10400.0000
# std            61702.761439     0.928191               2762.3847
# ...

# %%
data2.describe()
# Out:
#         Unnamed: 0  Kurulus_tarihi  Veri_analistci_tecrubesi  Isci_sayisi  \
# count  1001.000000     1001.000000               1001.000000  1001.000000
# mean    500.000000     1987.914086                  3.326673  2768.960040
# std     289.108111       14.484910                  1.100081   799.862924
# min       0.000000     1956.000000                  1.000000  1010.000000
# 25%     250.000000     1977.000000                  2.000000  2156.000000
# 50%     500.000000     1987.000000                  3.000000  2700.000000
# 75%     750.000000     1999.000000                  4.000000  3312.000000
# max    1000.000000     2019.000000                  5.000000  4203.000000
#
#        Isci__memnuniyeti  Aylik_uretim_miktari  Uretim_hizi  \
# count        1001.000000           1001.000000  1001.000000
# mean            2.912088         333895.904096     3.666334
# std             1.525209         127474.696364     1.193547
# ...

# %%
data1.shape
#Kaç verimiz olduğunu görüyoruz.
# Out:
# (101, 71)

# %%
data2.shape
# Out:
# (1001, 72)

# %%
data1.isna()
#kayıp verileri bluyoruz doğruluk amaçlı.
# Out:
#      Unnamed: 0  Factory   Ulke  SehIr  Tarih  Kurulus_tarihi  \
# 0         False    False  False  False  False           False
# 1         False    False  False  False  False           False
# 2         False    False  False  False  False           False
# 3         False    False  False  False  False           False
# 4         False    False  False  False  False           False
# ..          ...      ...    ...    ...    ...             ...
# 96         True     True   True   True   True            True
# 97         True     True   True   True   True            True
# 98         True     True   True   True   True            True
# 99         True     True   True   True   True            True
# 100        True     True   True   True   True            True
#
#      Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# 0                       False        False              False
# 1                       False        False              False
# ...

# %%
data2.isna()
# Out:
#       Unnamed: 0  Factory   Ulke  Sehir  Tarih  Kurulus_tarihi  \
# 0          False    False  False  False  False           False
# 1          False    False  False  False  False           False
# 2          False    False  False  False  False           False
# 3          False    False  False  False  False           False
# 4          False    False  False  False  False           False
# ...          ...      ...    ...    ...    ...             ...
# 996        False    False  False  False  False           False
# 997        False    False  False  False  False           False
# 998        False    False  False  False  False           False
# 999        False    False  False  False  False           False
# 1000       False    False  False  False  False           False
#
#       Veri_analistci_tecrubesi  Isci_sayisi  Isci__memnuniyeti  \
# 0                        False        False              False
# 1                        False        False              False
# ...

# %%
data1.isna().sum().sum()
#4331 kaybımız gözüküyor.
# Out:
# 4331

# %%
data2.isna().sum().sum()
# Out:
# 0

# %%
data1.isna().sum().sum() / data1.shape[0] * 100
#Kayıp verilerin yüzdesel oranı.
# Out:
# 4288.118811881189

# %%
data1_new = data1.dropna()
#kayıp verileri doğruluk açısından kaldırıyoruz.Ve yeni değişkeni atıyoruz bu haliyle devam etmek için.
#inplace=True vererek değişken atamadan devam edebilirdik.

# %%
data1.shape
#data1 eski halindeki verileri
# Out:
# (101, 71)

# %%
data1_new.shape
#yukarıda atanan yeni değişken istediğimiz şekilde.
# Out:
# (40, 71)

# %%
data1_new.isna().sum()
#sildiğimiz verilerin doğruluğu
# Out:
# Unnamed: 0                   0
# Factory                      0
# Ulke                         0
# SehIr                        0
# Tarih                        0
#                             ..
# Ortaklik_sorunlari           0
# Dunya_ekonomisi_cokusleri    0
# Yazilim_gelistirmeleri       0
# calisma_veduzenli_uretim     0
# Muhasebeci_tecrubesi         0
# Length: 71, dtype: int64

# %%
data1_new
#temize çekilmiş data1 verileri
# Out:
#     Unnamed: 0    Factory     Ulke      SehIr       Tarih Kurulus_tarihi  \
# 0          0.0   FABRIKA1  TurkIye   Istanbul  12.05.2020      1.01.2011
# 1          1.0   FABRIKA1  TurkIye   Istanbul  12.05.2020      1.01.2011
# 2          2.0   FABRIKA1  TurkIye   Istanbul  12.05.2020      1.01.2011
# 3          3.0   FABRIKA1  TurkIye   Istanbul  12.05.2020      1.01.2011
# 4          4.0   FABRIKA2  TurkIye      Adana  12.05.2020      1.01.2012
# 5          5.0   FABRIKA2  TurkIye      Adana  12.05.2020      1.01.2012
# 6          6.0   FABRIKA2  TurkIye      Adana  12.05.2020      1.01.2012
# 7          7.0   FABRIKA2  TurkIye      Adana  12.05.2020      1.01.2012
# 8          8.0   FABRIKA3  TurkIye    GIresun  12.05.2020      1.01.2013
# 9          9.0   FABRIKA3  TurkIye    GIresun  12.05.2020      1.01.2013
# 10        10.0   FABRIKA3  TurkIye    GIresun  12.05.2020      1.01.2013
# 11        11.0   FABRIKA3  TurkIye    GIresun  12.05.2020      1.01.2013
# ...

# %%
data1_new["Factory"].value_counts()
#verideki fabrikalar
# Out:
# FABRIKA10    4
# FABRIKA2     4
# FABRIKA4     4
# FABRIKA6     4
# FABRIKA8     4
# FABRIKA7     4
# FABRIKA1     4
# FABRIKA3     4
# FABRIKA9     4
# FABRIKA5     4
# Name: Factory, dtype: int64

# %%
data1["Ulke"].value_counts()
# Out:
# TurkIye    40
# Name: Ulke, dtype: int64

# %%
data2["Ulke"].value_counts()
# Out:
# Turkiye    1001
# Name: Ulke, dtype: int64

# %%
data1_deng =data1_new[["Factory","Tarih", "Veri_analistci_tecrubesi", "Max_kar", "Max_zarar", "Max_fiyat","Yonetici_sayisi","Min_zarar"]]
#istediğimiz verileri çekiyoruz.

# %%
data2_deng = data2[["Factory","Tarih", "Veri_analistci_tecrubesi", "Max_kar", "Max_zarar", "Max_fiyat", "Yonetici_sayisi"]]
#Önemli olarak görülebilecek verileri çekiyoruz.

# %%
data1_deng
# Out:
#       Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 0    FABRIKA1  12.05.2020                       5.0   3000.0        0.0
# 1    FABRIKA1  12.05.2020                       5.0   3000.0        0.0
# 2    FABRIKA1  12.05.2020                       5.0   3000.0        0.0
# 3    FABRIKA1  12.05.2020                       5.0   3000.0        0.0
# 4    FABRIKA2  12.05.2020                       4.0    300.0        0.0
# 5    FABRIKA2  12.05.2020                       4.0    300.0        0.0
# 6    FABRIKA2  12.05.2020                       4.0    300.0        0.0
# 7    FABRIKA2  12.05.2020                       4.0    300.0        0.0
# 8    FABRIKA3  12.05.2020                       5.0    270.0        0.0
# 9    FABRIKA3  12.05.2020                       5.0    270.0        0.0
# 10   FABRIKA3  12.05.2020                       5.0    270.0        0.0
# 11   FABRIKA3  12.05.2020                       5.0    270.0        0.0
# ...

# %%
data2_deng
# Out:
#           Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 0        Factory1  12.05.2020                         5       90         50
# 1        Factory2  12.05.2020                         3        0         70
# 2        Factory3  12.05.2020                         4       10         30
# 3        Factory4  12.05.2020                         2      100          0
# 4        Factory5  12.05.2020                         3       50         20
# ...           ...         ...                       ...      ...        ...
# 996    Factory997  12.05.2020                         2       33         28
# 997    Factory998  12.05.2020                         4      120         15
# 998    Factory999  12.05.2020                         5      125         22
# 999   Factory1000  12.05.2020                         4      130         42
# 1000  Factory1001  12.05.2020                         3      130         42
#
#       Max_fiyat  Yonetici_sayisi
# ...

# %%
data1_new["Veri_analistci_tecrubesi"]
#kendi fabrikalarımızdaki veri analizi eksikliği.0 değerinde 2 fabrika var bu fabrikalar 5. ve 8. fabrikalar.
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 3     5.0
# 4     4.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     5.0
# 9     5.0
# 10    5.0
# 11    5.0
# 12    4.0
# 13    4.0
# 14    4.0
# 15    4.0
# 16    0.0
# 17    0.0
# 18    0.0
# 19    0.0
# 20    5.0
# 21    5.0
# 22    5.0
# 23    5.0
# 24    5.0
# 25    5.0
# 26    5.0
# 27    5.0
# 28    0.0
# 29    0.0
# 30    0.0
# 31    0.0
# 32    3.0
# 33    3.0
# 34    3.0
# 35    3.0
# 36    5.0
# 37    5.0
# 38    5.0
# 39    5.0
# Name: Veri_analistci_tecrubesi, dtype: float64

# %%
data2["Veri_analistci_tecrubesi"]
# Out:
# 0       5
# 1       3
# 2       4
# 3       2
# 4       3
#        ..
# 996     2
# 997     4
# 998     5
# 999     4
# 1000    3
# Name: Veri_analistci_tecrubesi, Length: 1001, dtype: int64

# %%
data1_deng[data1_deng["Max_zarar"] < 0]
#Hangi fabrikaların zarar ettiğini
# Out:
#      Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 16  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 17  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 18  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 19  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 28  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 29  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 30  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 31  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
#
#     Max_fiyat  Yonetici_sayisi
# 16      190.0              1.0
# 17      190.0              1.0
# 18      190.0              1.0
# 19      190.0              1.0
# 28      200.0              1.0
# 29      200.0              1.0
# 30      200.0              1.0
# 31      200.0              1.0

# %%
data2_deng[data2_deng["Max_zarar"] <= 0]
#1000 fabrikanın zarar durumunun 0 ve üstünde olan fabrikaların listelenmesi.
# Out:
#         Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 3      Factory4  12.05.2020                         2      100          0
# 20    Factory21  12.05.2020                         5      100          0
# 37    Factory38  12.05.2020                         2      100          0
# 54    Factory55  12.05.2020                         4      100          0
# 71    Factory72  12.05.2020                         5      100          0
# 88    Factory89  12.05.2020                         1      100          0
# 105  Factory106  12.05.2020                         2      100          0
# 122  Factory123  12.05.2020                         3      100          0
# 139  Factory140  12.05.2020                         4      100          0
# 156  Factory157  12.05.2020                         5      100          0
# 173  Factory174  12.05.2020                         4      100          0
# 190  Factory191  12.05.2020                         4      100          0
# ...

# %%
data1_deng[(data1_deng["Factory"] == "FABRIKA5") & (data1_deng["Veri_analistci_tecrubesi"] <= 0)]
#zarar eden fabrikalarımızın verileri.
# Out:
#      Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 16  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 17  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 18  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
# 19  FABRIKA5  12.05.2020                       0.0   -960.0    -1300.0
#
#     Max_fiyat  Yonetici_sayisi
# 16      190.0              1.0
# 17      190.0              1.0
# 18      190.0              1.0
# 19      190.0              1.0

# %%
df5 = data1_deng[(data1_deng["Factory"] == "FABRIKA5") & (data1_deng["Veri_analistci_tecrubesi"] <= 0)]
#df 5 değişkeni Fabrika5(Ankara) ve fabrikadaki veri analizci puanlamasını birlikte gösteriyor.Veri analizci eksikliğinden kaynaklanan zarar durumları göz önüne geliyor.

# %%
data1_deng[(data1_deng["Factory"] == "FABRIKA8") & (data1_deng["Veri_analistci_tecrubesi"] <= 0)]
#Fabrika8(Gumushane) ve fabrika analizcinin 0 puanlı olan verilerini listeliyoruz. Aşağıda df8 değişkenine atıyoruz.
# Out:
#      Factory       Tarih  Veri_analistci_tecrubesi  Max_kar  Max_zarar  \
# 28  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 29  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 30  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
# 31  FABRIKA8  12.05.2020                       0.0  -1260.0    -1600.0
#
#     Max_fiyat  Yonetici_sayisi
# 28      200.0              1.0
# 29      200.0              1.0
# 30      200.0              1.0
# 31      200.0              1.0

# %%
df8 = data1_deng[(data1_deng["Factory"] == "FABRIKA8") & (data1_deng["Veri_analistci_tecrubesi"] <= 0)]

# %%
data1_new.groupby(by="Factory").min()
#Kendi fabrikalarımızdaki Factory başlığının minimum değerlerini alıyoruz.
# Out:
#            Unnamed: 0     Ulke      SehIr       Tarih Kurulus_tarihi  \
# Factory
# FABRIKA1          0.0  TurkIye   Istanbul  12.05.2020      1.01.2011
# FABRIKA10        36.0  TurkIye      Hatay  12.05.2020      1.01.2020
# FABRIKA2          4.0  TurkIye      Adana  12.05.2020      1.01.2012
# FABRIKA3          8.0  TurkIye    GIresun  12.05.2020      1.01.2013
# FABRIKA4         12.0  TurkIye    Sakarya  12.05.2020      1.01.2014
# FABRIKA5         16.0  TurkIye     Ankara  12.05.2020      1.01.2015
# FABRIKA6         20.0  TurkIye    Trabzon  12.05.2020      1.01.2016
# FABRIKA7         24.0  TurkIye       RIze  12.05.2020      1.01.2017
# FABRIKA8         28.0  TurkIye  Gumushane  12.05.2020      1.01.2018
# FABRIKA9         32.0  TurkIye    Malatya  12.05.2020      1.01.2019
#
#            Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# Factory
# FABRIKA1                        5.0       2545.0                5.0
# ...

# %%
data1_new.groupby(by="Factory").max()
#Kendi fabrikalarımızdaki Factory başlığının maximum değerlerini alıyoruz.
# Out:
#            Unnamed: 0     Ulke      SehIr       Tarih Kurulus_tarihi  \
# Factory
# FABRIKA1          3.0  TurkIye   Istanbul  12.05.2020      1.01.2011
# FABRIKA10        39.0  TurkIye      Hatay  12.05.2020      1.01.2020
# FABRIKA2          7.0  TurkIye      Adana  12.05.2020      1.01.2012
# FABRIKA3         11.0  TurkIye    GIresun  12.05.2020      1.01.2013
# FABRIKA4         15.0  TurkIye    Sakarya  12.05.2020      1.01.2014
# FABRIKA5         19.0  TurkIye     Ankara  12.05.2020      1.01.2015
# FABRIKA6         23.0  TurkIye    Trabzon  12.05.2020      1.01.2016
# FABRIKA7         27.0  TurkIye       RIze  12.05.2020      1.01.2017
# FABRIKA8         31.0  TurkIye  Gumushane  12.05.2020      1.01.2018
# FABRIKA9         35.0  TurkIye    Malatya  12.05.2020      1.01.2019
#
#            Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# Factory
# FABRIKA1                        5.0       2545.0                5.0
# ...

# %%
data2.groupby(by="Factory").min()
#Değerlendirilen fabrikaların minimum değerlerini verisine göre listeliyoruz.
# Out:
#              Unnamed: 0     Ulke      Sehir       Tarih  Kurulus_tarihi  \
# Factory
# Factory1              0  Turkiye      Adana  12.05.2020            1980
# Factory10             9  Turkiye      Hatay  12.05.2020            1993
# Factory100           99  Turkiye      Hatay  12.05.2020            1988
# Factory1000         999  Turkiye      Hatay  12.05.2020            2012
# Factory1001        1000  Turkiye    Kocaeli  12.05.2020            2009
# ...                 ...      ...        ...         ...             ...
# Factory995          994  Turkiye     Ankara  12.05.2020            2005
# Factory996          995  Turkiye    Trabzon  12.05.2020            2010
# Factory997          996  Turkiye       Rize  12.05.2020            1956
# Factory998          997  Turkiye  Gumushane  12.05.2020            1976
# Factory999          998  Turkiye    Malatya  12.05.2020            2019
#
#              Veri_analistci_tecrubesi  Isci_sayisi  Isci__memnuniyeti  \
# Factory
# ...

# %%
data1_selected = data1_new.groupby(by="Factory").mean()
#Factory başlığı altında grup olarak alıyoruz.

# %%
data1_selected
# Out:
#            Unnamed: 0  Veri_analistci_tecrubesi  isci_sayisi  \
# Factory
# FABRIKA1          1.5                       5.0       2545.0
# FABRIKA10        37.5                       5.0       3780.0
# FABRIKA2          5.5                       4.0       3200.0
# FABRIKA3          9.5                       5.0       3700.0
# FABRIKA4         13.5                       4.0       2250.0
# FABRIKA5         17.5                       0.0       1900.0
# FABRIKA6         21.5                       5.0       2670.0
# FABRIKA7         25.5                       5.0       3530.0
# FABRIKA8         29.5                       0.0       1750.0
# FABRIKA9         33.5                       3.0       3365.0
#
#            isci__memnuniyeti  Aylik_uretim_miktari  Uretim_hizi  \
# Factory
# FABRIKA1                 5.0              330000.0          4.0
# FABRIKA10                5.0              355000.0          4.0
# FABRIKA2                 4.0              350000.0          3.0
# ...

# %%
Ankara = pd.read_csv("Ankara.csv", index_col=0)
#Zarar eden fabrikalardan biri olan Fabrika5(Ankara) fabrikasını başındaki veriyi silerek değişkene atıyoruz

# %%
Gumushane = pd.read_csv("Gümüşhane.csv",index_col=0)
#Zarar eden fabrikalardan biri olan Fabrika8(Gumushane) fabrikasını başındaki veriyi silerek değişkene atıyoruz

# %%
Ankara.head()
# Out:
#          Tarih  Gunluk_uretim_miktari
# 0.0  1.01.2020                12000.0
# 1.0  2.01.2020                12450.0
# 2.0  3.01.2020                12630.0
# 3.0  4.01.2020                12300.0
# 4.0  5.01.2020                12100.0

# %%
Ankara.shape
# Out:
# (367, 2)

# %%
Ankara.describe()
# Out:
#        Gunluk_uretim_miktari
# count             366.000000
# mean             8389.316940
# std              4810.338067
# min              1000.000000
# 25%              3200.000000
# 50%              9000.000000
# 75%             12681.250000
# max             15400.000000

# %%
sns.displot(Ankara)
#Ankara fabrikasının üretim miktarlarını görüyoruz

# %%
Gumushane.head()
# Out:
#    Unnamed: 0      Tarih  Urunbasi_ortalama_maliyet
# 0         0.0  1.01.2020                      210.0
# 1         1.0  2.01.2020                      210.0
# 2         2.0  3.01.2020                      210.0
# 3         3.0  4.01.2020                      210.0
# 4         4.0  5.01.2020                      210.0

# %%
Gumushane.shape
# Out:
# (367, 3)

# %%
Gumushane.describe()
# Out:
#        Unnamed: 0  Urunbasi_ortalama_maliyet
# count  366.000000                 366.000000
# mean   182.500000                 436.079235
# std    105.799338                 176.583627
# min      0.000000                 200.000000
# 25%     91.250000                 240.000000
# 50%    182.500000                 440.000000
# 75%    273.750000                 500.000000
# max    365.000000                 800.000000

# %%
sns.displot(Gumushane)
#Gumushane fabrikasının üretim miktarları.Maliyetlerin normalden zamanla daha yüksek olduğunu görüyoruz

# %%
data1_new.describe()
# Out:
#        Unnamed: 0  Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# count   40.000000                 40.000000    40.000000          40.000000
# mean    19.500000                  3.600000  2869.000000           4.000000
# std     11.690452                  1.932184   718.391365           1.012739
# min      0.000000                  0.000000  1750.000000           2.000000
# 25%      9.750000                  3.000000  2250.000000           3.000000
# 50%     19.500000                  4.500000  2935.000000           4.000000
# 75%     29.250000                  5.000000  3530.000000           5.000000
# max     39.000000                  5.000000  3780.000000           5.000000
#
#        Aylik_uretim_miktari  Uretim_hizi  Gunluk_uretilen_miktar  \
# count             40.000000    40.000000                 40.0000
# mean          315500.000000     3.600000              10400.0000
# std            61702.761439     0.928191               2762.3847
# ...

# %%
grf=data1_new.describe()

# %%
grf[["Veri_analistci_tecrubesi"]]
#verilere bakarak çok yüksek miktarda veri analizi tecrübesi olmadığını görüyoruz.
# Out:
#        Veri_analistci_tecrubesi
# count                 40.000000
# mean                   3.600000
# std                    1.932184
# min                    0.000000
# 25%                    3.000000
# 50%                    4.500000
# 75%                    5.000000
# max                    5.000000

# %%
Yonetim =data1_new[["Factory","Tarih", "Veri_analistci_tecrubesi", "Musteri_hizmetlerinin_ilgisi", "Patronlarin_donanimi", "Yonetici_sayisi","Ortaklarla_uyum","Aylik_toplanti","Ceo_degisimi"]]

# %%
sns.displot(data1_deng)

# %%
sns.displot(Yonetim)

# %%
path = "https://raw.githubusercontent.com/alperdbs/homework/main/homeworkcsv"
df = pd.read_csv(path,header=0)
print(df.shape)
print(df.head())
# Out:
# (40, 71)
#    Unnamed: 0   Factory     Ulke     SehIr       Tarih Kurulus_tarihi  \
# 0           0  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 1           1  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 2           2  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 3           3  FABRIKA1  TurkIye  Istanbul  12.05.2020      1.01.2011
# 4           4  FABRIKA2  TurkIye     Adana  12.05.2020      1.01.2012
#
#    Veri_analistci_tecrubesi  isci_sayisi  isci__memnuniyeti  \
# 0                         5         2545                  5
# 1                         5         2545                  5
# 2                         5         2545                  5
# 3                         5         2545                  5
# 4                         4         3200                  4
#
#    Aylik_uretim_miktari  ...  Musteri_hizmetlerinin_ilgisi  Yanlis_strateji  \
# 0                330000  ...                             5               NO
# ...

# %%
df1=df[["Tarih","Aylik_uretim_miktari"]]

# %%
from matplotlib import pyplot
df1.plot()
pyplot.show()

# %%
path1 = "https://raw.githubusercontent.com/alperdbs/homework/main/ankara"
df2 = pd.read_csv(path1,header=0)
print(df2.shape)
print(df2.head())
# Out:
# (367, 3)
#    Unnamed: 0      Tarih  Gunluk_uretim_miktari
# 0         0.0  1.01.2020                12000.0
# 1         1.0  2.01.2020                12450.0
# 2         2.0  3.01.2020                12630.0
# 3         3.0  4.01.2020                12300.0
# 4         4.0  5.01.2020                12100.0

# %%
df3=df2[["Tarih","Gunluk_uretim_miktari"]]

# %%
df3.plot()
pyplot.show()

# %%
path2 = "https://raw.githubusercontent.com/alperdbs/homework/main/gumushane"
df3 = pd.read_csv(path2,header=0)
print(df3.shape)
print(df3.head())
# Out:
# (366, 3)
#    Unnamed: 0      Tarih  Urunbasi_ortalama_maliyet
# 0           0  1.01.2020                        210
# 1           1  2.01.2020                        210
# 2           2  3.01.2020                        210
# 3           3  4.01.2020                        210
# 4           4  5.01.2020                        210

# %%
df4=df3[["Tarih","Urunbasi_ortalama_maliyet"]]

# %%
df4.plot()
pyplot.show()
