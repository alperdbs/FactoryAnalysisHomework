# %%
# %pip install --upgrade scikit-learn==0.23.0
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot
# Out:
# Requirement already satisfied: scikit-learn==0.23.0 in c:\users\alper\anaconda3\lib\site-packages (0.23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alper\anaconda3\lib\site-packages (from scikit-learn==0.23.0) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\alper\anaconda3\lib\site-packages (from scikit-learn==0.23.0) (1.20.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\alper\anaconda3\lib\site-packages (from scikit-learn==0.23.0) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\alper\anaconda3\lib\site-packages (from scikit-learn==0.23.0) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
path = 'https://raw.githubusercontent.com/alperdbs/homework/main/ankara'
df = pd.read_csv(path, header=0)

df1= df[["Tarih","Gunluk_uretim_miktari"]]
df1.plot()
pyplot.show()

# %%
import numpy as np
import pandas as pd
input_file = "Ankara.csv"

df = pd.read_csv(input_file, header = 0)

# for space delimited use:
#df = pd.read_csv(input_file, header = 0, delimiter = " ")

# for tab delimited use:
#df = pd.read_csv(input_file, header = 0, delimiter = "\t")

# put the original column names in a python list(sutun adlarıyla python listesi oluştur)
original_headers = list(df.columns.values)

# remove the non-numeric columns(içinde string olan verileri sil)
df = df._get_numeric_data()

# put the numeric column names in a python list(sutun adlarını sayısal olarak belirt)
numeric_headers = list(df.columns.values)

# create a numpy array with the numeric values for input into scikit-learn(veriler ile scikit-learn e uygun dizi oluştur)
numpy_array = df.values

# reverse the order of the columns(sutunları düzelt)
numeric_headers.reverse()
reverse_df = df[numeric_headers]

#data değişkeninin içine diziyi koy
data = numpy_array

#yapay zekanın öğrenmesi için veri kümeleri oluştur
X = data[:, 1:]  # select columns 1 through end
y = data[:, 0]   # select column 0, the stock price

#sklearn kütüphanesinden sınıfı import ed
from sklearn.neighbors import KNeighborsRegressor

#mod adında model oluştur
mod = KNeighborsRegressor()
data = df.filter(['Close'])
dataset = data.values
#dataset

# %%
mod.fit(X, y)
alper = mod.predict(X)
alper
# Out:
# array([12620.4, 12884. , 12492. , 12582. , 12685. , 12625. , 12278. ,
#        12686. , 12622.4, 12620.4, 12688.8, 12674.8, 12916. , 12421. ,
#        12900. , 12875.8, 12870. , 12900. , 12896. , 12454.4, 12620.4,
#        12421. , 12688.8, 12674.8, 12390.2, 12355. , 12261. , 12482. ,
#        12492. , 12584. , 12416. , 12686. , 12701. , 12703. , 12625. ,
#        12918. , 12919. , 13032. , 12906. , 13153. , 13150. , 13238.2,
#        13017.6, 13158. , 13172. , 12916. , 12620.4, 12916. , 12868. ,
#        12870. , 12875.8, 12918. , 12919. , 13032. , 12906. , 13153. ,
#        13150. , 13238.2, 13017.6, 13158. , 13172. , 13238. , 12906. ,
#        13153. , 13150. , 13238.2, 13017.6, 13158. , 13172. , 12916. ,
#        12620.4, 12916. , 12868. , 12870. , 12875.8, 12918. , 12919. ,
#        13032. , 12906. , 13153. , 13150. , 13238.2, 13017.6, 13893. ,
#        14084. , 14000. , 14000. , 13941. , 13893. , 13594. , 13566. ,
#        13856. , 13720. , 13508. , 13238. , 13172. , 13238.2, 13153. ,
#        13160. , 12916. , 12679.8, 12492. , 12703. , 12582. , 13072. ,
#        13092. , 14212. , 14632. , 14840. , 15050. , 15192. , 15250. ,
#        15296. , 13104. , 12246. , 14998. , 14998. , 14998. , 14280. ,
